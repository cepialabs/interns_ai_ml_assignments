# %% [markdown]
# # 20 Basic Python Programs

# %%
print("Hello, World!")

# %%
a=int(input("Enter first number: ")); b=int(input("Enter second number: ")); print("Sum:",a+b)

# %%
n=int(input()); print("Even" if n%2==0 else "Odd")

# %%
a=int(input()); b=int(input()); print("Largest:", a if a>b else b)

# %%
a=int(input()); b=int(input()); c=int(input()); print("Largest:", max(a,b,c))

# %%
n=int(input()); print("Positive" if n>0 else "Negative" if n<0 else "Zero")

# %%
n=int(input()); fact=1
for i in range(1,n+1): fact*=i
print("Factorial:",fact)

# %%
n=int(input()); flag=True
for i in range(2,n):
    if n%i==0:
        flag=False; break
print("Prime" if flag and n>1 else "Not Prime")

# %%
n=int(input());
for i in range(1,n+1): print(i)

# %%
n=int(input()); print("Sum:", n*(n+1)//2)

# %%
n=int(input()); rev=0
while n>0:
    rev=rev*10+n%10; n//=10
print("Reverse:",rev)

# %%
n=int(input()); temp=n; rev=0
while n>0:
    rev=rev*10+n%10; n//=10
print("Palindrome" if temp==rev else "Not Palindrome")

# %%
n=int(input()); s=0
while n>0:
    s+=n%10; n//=10
print("Sum of digits:",s)

# %%
a=int(input()); b=int(input()); a,b=b,a; print("a:",a,"b:",b)

# %%
c=float(input()); print("Fahrenheit:", (c*9/5)+32)

# %%
y=int(input()); print("Leap Year" if y%400==0 or (y%4==0 and y%100!=0) else "Not Leap Year")

# %%
n=int(input()); print("Square:",n*n,"Cube:",n*n*n)

# %%
s=input().lower(); print("Vowels:", sum(1 for ch in s if ch in "aeiou"))

# %%
s=input(); count=0
for _ in s: count+=1
print("Length:",count)

# %%
n=int(input());
for i in range(1,11): print(f"{n} x {i} = {n*i}")
