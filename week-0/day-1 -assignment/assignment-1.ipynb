# %%
#1.add two numbers
a=10
b=30
print(a+b)
# Out:
# 40

# %%
#2.Even or odd
num=13574
if num%2==0:
   print("even")
else:
    print("odd")
# Out:
# even

# %%
#3.Largest of three numbers
a,b,c=22,50,65
print(max(a,b,c))
# Out:
# 65

# %%
#4.swap two variables
a=4
b=6
a,b=b,a
print(a,b)
# Out:
# 6 4

# %%
#5.factorial
n=4
fact=1
for i in range(1, n+1):
    fact*=i
print(fact)
# Out:
# 24

# %%
#6.check leap year
def checkyear(year):
    return(((year % 4 ==0) and (year % 100 !=0)) or (year % 400 ==0))
year=2026
if checkyear(year):
    print("it is a leap year")
else:
    print("it is not leap year")
# Out:
# it is not leap year

# %%
#7.string formatting
name="Bindu"
marks=88
print(f"{name} scored {marks} marks")
# Out:
# Bindu scored 88 marks

# %%
#8.count vowels in string
text = "artificial intelligence"
vowels = "aeiouAEIOU"

count = 0
for ch in text:
    if ch in vowels:
        count += 1

print("Number of vowels:", count)
# Out:
# Number of vowels: 10

# %%
#9.reversing string
def reverse_string(s):
    return s[::-1]

print(reverse_string("Bindu"))
# Out:
# udniB

# %%
#10.find positive,negative and zero
num =  int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
#11.palindrome
text = input("Enter a string: ")

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
#12.fibonacci
def fibonacci(n):
    a, b = 0, 1
    for _ in range(n):
        print(a, end=" ")
        a, b = b, a + b

fibonacci(7)
# Out:
# 0 1 1 2 3 5 8

# %%
#13.removing duplicates
lst=[1,2,2,2,3,3,4,4,4,5,6,7,7,8,9,9]
print(list(set(lst)))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#14.armstrong
def is_armstrong(num):
    s = str(num)
    power = len(s)
    total = sum(int(d)**power for d in s)
    return total == num

print(is_armstrong(153))
# Out:
# True

# %%
#15.converting list to dictonary
lst = ["a", "b", "c"]
d = {}

for i in range(len(lst)):
    d[i] = lst[i]

print(d)
# Out:
# {0: 'a', 1: 'b', 2: 'c'}

# %%
#16.Finding dates 
from datetime import datetime, timedelta

presentday = datetime.now()
yesterday = presentday - timedelta(days=1)
tomorrow  = presentday + timedelta(days=1)

print("Yesterday:", yesterday.strftime('%d-%m-%Y'))
print("Today:", presentday.strftime('%d-%m-%Y'))
print("Tomorrow:", tomorrow.strftime('%d-%m-%Y'))
# Out:
# Yesterday: 15-01-2026
# Today: 16-01-2026
# Tomorrow: 17-01-2026

# %%
#17.sum of array
arr = [12, 3, 4, 15]
ans = sum(arr)
print('Sum:', ans)
# Out:
# Sum: 34

# %%
#18.Generating a random string
import random
import string

def randomString(stringLength):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(stringLength))

print ("Random String is ", randomString(5) )
# Out:
# Random String is  mzHyu

# %%
#19.missing number
def missing_number(arr, n):
    expected = sum(range(1, n + 1))
    actual = sum(arr)
    return expected - actual

print(missing_number([1,2,4,5], 5))
# Out:
# 3

# %%
#20.using encapsulation
class Employee:
    # constructor
    def __init__(self, name, salary, project):
        # data members
        self.name = name
        self.salary = salary
        self.project = project

    # method
    # to display employee's details
    def show(self):
        print("Name: ", self.name, 'Salary:', self.salary)

    # method
    def work(self):
        print(self.name, 'is working as', self.project)

# creating object of a class
emp = Employee('Bindu', 15000, 'Associate')

# calling public method of the class
emp.show()
emp.work()
# Out:
# Name:  Bindu Salary: 15000
# Bindu is working as Associate

# %% [markdown]
# #short note
# I want to build a career in AI and Machine Learning because it combines logic, creativity, and real-world problem solving. What attracts me most is how AI/ML can turn raw data into meaningful insights and intelligent solutions that impact everyday life—such as healthcare, education, and automation.
#
# Coming from a non-IT background, learning AI/ML has motivated me to continuously upskill and challenge myself. The field is constantly evolving, which pushes me to stay curious and adaptable. I enjoy working with data, understanding patterns, and building models that can learn and improve over time.
#
# I believe a career in AI/ML will allow me to grow technically while contributing to innovative solutions that make processes smarter, faster, and more efficient.
