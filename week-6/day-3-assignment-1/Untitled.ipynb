# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load MNIST Dataset

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# ### Normalize Data

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Convert Labels to Categorical

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# ### Build Neural Network Model

# %%
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# ### Compile Model (Categorical Cross Entropy)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### Train the Model

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9254 - loss: 0.2603 - val_accuracy: 0.9544 - val_loss: 0.1509
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9657 - loss: 0.1162 - val_accuracy: 0.9642 - val_loss: 0.1154
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9758 - loss: 0.0816 - val_accuracy: 0.9723 - val_loss: 0.0885
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9819 - loss: 0.0614 - val_accuracy: 0.9761 - val_loss: 0.0832
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9857 - loss: 0.0466 - val_accuracy: 0.9781 - val_loss: 0.0749
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9888 - loss: 0.0368 - val_accuracy: 0.9777 - val_loss: 0.0722
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9907 - loss: 0.0295 - val_accuracy: 0.9759 - val_loss: 0.0758
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9927 - loss: 0.0237 - val_accuracy: 0.9770 - val_loss: 0.0801
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9941 - loss: 0.0198 - val_accuracy: 0.9802 - val_loss: 0.0714
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9954 - loss: 0.0154 - val_accuracy: 0.9781 - val_loss: 0.0812

# %% [markdown]
# ### Plot Training Loss Across Epochs

# %%
plt.plot(history.history['loss'])
plt.xlabel("Epochs")
plt.ylabel("Training Loss")
plt.title("Training Loss Across Epochs")
plt.show()

# %% [markdown]
# ### Evaluate Model

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9781 - loss: 0.0812
# Test Accuracy: 0.9781000018119812
