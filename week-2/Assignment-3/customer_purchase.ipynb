# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Reproducibility
np.random.seed(42)

# Simulated customer purchase amounts (₹)
purchase_amounts = np.random.normal(loc=2500, scale=600, size=1000)

df = pd.DataFrame({
    "purchase_amount": purchase_amounts
})

df.head()
# Out:
#    purchase_amount
# 0      2798.028492
# 1      2417.041419
# 2      2888.613123
# 3      3413.817914
# 4      2359.507975

# %%
# Calculate mean and standard deviation
mean = df["purchase_amount"].mean()
std = df["purchase_amount"].std()

# %%
# Histogram
plt.figure()
plt.hist(df["purchase_amount"], bins=30, density=True)

# Normal distribution curve
x = np.linspace(df["purchase_amount"].min(), df["purchase_amount"].max(), 100)
pdf = norm.pdf(x, mean, std)

# %%
plt.plot(x, pdf)
plt.xlabel("Purchase Amount")
plt.ylabel("Density")
plt.title("Histogram of Customer Purchase Amounts with Normal Fit")
plt.show()

# %%
threshold = 3000  # example threshold

# Probability using normal distribution
probability_above_threshold = 1 - norm.cdf(threshold, mean, std)

probability_above_threshold
# Out:
# 0.20290812376163636

# %%
# Simulated theoretical sales data using same mean & std
simulated_sales = np.random.normal(mean, std, 1000)

plt.figure()
plt.hist(df["purchase_amount"], bins=30, density=True, alpha=0.6, label="Actual Data")
plt.hist(simulated_sales, bins=30, density=True, alpha=0.6, label="Simulated Data")
# Out:
# (array([4.16249222e-05, 2.49749533e-05, 3.32999377e-05, 4.16249222e-05,
#         4.99499066e-05, 1.16549782e-04, 1.83149657e-04, 2.16449595e-04,
#         2.58074517e-04, 4.07924237e-04, 4.07924237e-04, 5.57773957e-04,
#         5.82748910e-04, 7.57573583e-04, 7.15948661e-04, 6.49348786e-04,
#         6.41023801e-04, 5.91073895e-04, 4.16249222e-04, 4.49549159e-04,
#         3.57974331e-04, 2.24774580e-04, 2.49749533e-04, 9.98998132e-05,
#         1.16549782e-04, 4.99499066e-05, 4.16249222e-05, 2.49749533e-05,
#         0.00000000e+00, 1.66499689e-05]),
#  array([ 784.03398419,  904.15432896, 1024.27467372, 1144.39501849,
#         1264.51536325, 1384.63570802, 1504.75605278, 1624.87639755,
#         1744.99674231, 1865.11708708, 1985.23743184, 2105.35777661,
#         2225.47812137, 2345.59846614, 2465.7188109 , 2585.83915567,
#         2705.95950043, 2826.0798452 , 2946.20018996, 3066.32053473,
#         3186.44087949, 3306.56122426, 3426.68156903, 3546.80191379,
# ...

# %%
plt.xlabel("Purchase Amount")
plt.ylabel("Density")
plt.title("Actual vs Simulated Sales Distribution")
plt.legend()
plt.show()
# Out:
# C:\Users\ansar\AppData\Local\Temp\ipykernel_24152\1342799238.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
