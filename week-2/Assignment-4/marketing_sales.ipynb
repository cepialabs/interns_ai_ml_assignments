# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("marketing_sales.csv")
df
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 0     16.0   6.566231      2.907983       Mega   54.732757
# 1     13.0   9.237765      2.409567       Mega   46.677897
# 2     41.0  15.886446      2.913410       Mega  150.177829
# 3     83.0  30.020028      6.922304       Mega  298.246340
# 4     15.0   8.437408      1.405998      Micro   56.594181
# ...    ...        ...           ...        ...         ...
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414
#
# [4572 rows x 5 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV            4562 non-null   float64
#  1   Radio         4568 non-null   float64
#  2   Social Media  4566 non-null   float64
#  3   Influencer    4572 non-null   object
#  4   Sales         4566 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 178.7+ KB
#                 TV        Radio  Social Media        Sales
# count  4562.000000  4568.000000   4566.000000  4566.000000
# mean     54.066857    18.160356      3.323956   192.466602
# std      26.125054     9.676958      2.212670    93.133092
# min      10.000000     0.000684      0.000031    31.199409
# 25%      32.000000    10.525957      1.527849   112.322882
# 50%      53.000000    17.859513      3.055565   189.231172
# 75%      77.000000    25.649730      4.807558   272.507922
# ...

# %%
numeric_df = df[['TV', 'Radio', 'Social Media', 'Sales']]
corr_matrix = numeric_df.corr()

corr_matrix
# Out:
#                     TV     Radio  Social Media     Sales
# TV            1.000000  0.869460      0.528168  0.999497
# Radio         0.869460  1.000000      0.607452  0.869105
# Social Media  0.528168  0.607452      1.000000  0.528906
# Sales         0.999497  0.869105      0.528906  1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Between Advertising Spend and Sales")
plt.show()

# %%
print("""
Correlation Interpretation
- Correlation measures the strength and direction of a linear relationship.
- A high positive correlation indicates that as ad spend increases, sales tend to increase.
- Correlation does not indicate cause-and-effect.
""")
# Out:
# Correlation Interpretation
# - Correlation measures the strength and direction of a linear relationship.
# - A high positive correlation indicates that as ad spend increases, sales tend to increase.
# - Correlation does not indicate cause-and-effect.

# %%
print("""
Correlation vs Causation

Correlation
- Shows association between variables
- Does not imply cause-and-effect
- Example: TV spend and sales increase together

Causation
- One variable directly affects another
- Requires controlled experiments or causal models

Key Rule: Correlation ≠ Causation
""")
# Out:
# Correlation vs Causation
#
# Correlation
# - Shows association between variables
# - Does not imply cause-and-effect
# - Example: TV spend and sales increase together
#
# Causation
# - One variable directly affects another
# - Requires controlled experiments or causal models
#
# Key Rule: Correlation ≠ Causation

# %%
print("""
Possible Confounders in Marketing Data

1. Seasonality (festivals, holidays)
2. Brand popularity
3. Discounts and promotions
4. Product quality
5. Competitor advertising
6. Economic conditions

These factors may influence both advertising spend and sales.
""")
# Out:
# Possible Confounders in Marketing Data
#
# 1. Seasonality (festivals, holidays)
# 2. Brand popularity
# 3. Discounts and promotions
# 4. Product quality
# 5. Competitor advertising
# 6. Economic conditions
#
# These factors may influence both advertising spend and sales.

# %%
print("""
Conclusion
While correlation analysis helps identify relationships between advertising spend and sales, it cannot establish causality. Confounding variables and external factors must be considered before drawing business conclusions.
""")
# Out:
# Conclusion
# While correlation analysis helps identify relationships between advertising spend and sales, it cannot establish causality. Confounding variables and external factors must be considered before drawing business conclusions.
