# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 10,000 random house prices
np.random.seed(42)
prices = np.random.normal(loc=300000, scale=75000, size=10000)

# Average price
average_price = prices.mean()
print("Average price:", round(average_price, 2))

# Remove outliers using IQR
Q1 = np.percentile(prices, 25)
Q3 = np.percentile(prices, 75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

filtered_prices = prices[(prices >= lower) & (prices <= upper)]

# Visualization
plt.figure()
plt.hist(filtered_prices, bins=50)
plt.title("House Price Distribution (Outliers Removed)")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()
# Out:
# Average price: 299839.8
