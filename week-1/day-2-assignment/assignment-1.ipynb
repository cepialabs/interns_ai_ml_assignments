# %% [markdown]
# Nernay Kumar
# Intern Id
# INT2026-9021

# %%
# Install required package (run this cell first)
# %pip install kagglehub

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mahmoudtaya/netflix-titles")
print("Path to dataset files:", path)

# Load the dataset CSV
csv_path = f"{path}/netflix_titles.csv"

df = pd.read_csv(csv_path)
print(df.head())
print(df.shape)

# %%
# 1. Top 10 most frequent genres

genres = df['listed_in'].dropna().str.split(',').explode().str.strip()

top_genres = genres.value_counts().head(10)
print(top_genres)

top_genres.plot(kind='bar', title='Top 10 Genres', figsize=(8, 4))
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# listed_in
# International Movies      1927
# Dramas                    1623
# Comedies                  1113
# International TV Shows    1001
# Documentaries              668
# TV Dramas                  599
# Action & Adventure         597
# Independent Movies         552
# TV Comedies                436
# Thrillers                  392
# Name: count, dtype: int64

# %%
# 2. Compare Movies vs TV Shows distribution

type_counts = df['type'].value_counts()
print(type_counts)

type_counts.plot(kind='pie', autopct='%1.1f%%', title='Movies vs TV Shows', figsize=(4, 4))
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %%
# 3. Analyze content added per year

df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year

content_per_year = df['year_added'].value_counts().sort_index()
print(content_per_year.tail(10))

content_per_year.plot(kind='line', title='Content Added Per Year', figsize=(8, 4))
plt.xlabel('Year')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# year_added
# 2011.0      13
# 2012.0       7
# 2013.0       9
# 2014.0      19
# 2015.0      74
# 2016.0     412
# 2017.0    1184
# 2018.0    1629
# 2019.0    2057
# 2020.0     174
# Name: count, dtype: int64

# %%
# 4. Identify country producing most content

countries = df['country'].dropna().str.split(',').explode().str.strip()

top_country = countries.value_counts().head(1)
print(top_country)

top_countries = countries.value_counts().head(10)
print(top_countries)

top_countries.plot(kind='bar', title='Top 10 Producing Countries', figsize=(8, 4))
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# country
# United States    2610
# Name: count, dtype: int64
# country
# United States     2610
# India              838
# United Kingdom     602
# Canada             318
# France             271
# Japan              231
# Spain              178
# South Korea        162
# Germany            151
# Mexico             129
# Name: count, dtype: int64
