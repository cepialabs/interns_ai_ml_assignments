# %%
#Import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Step 1: Generate 10,000 random house prices
np.random.seed(42)
house_prices = np.random.normal(loc=500000, scale=100000, size=10000)

# %%
# Step 2: Calculate average price
average_price = np.mean(house_prices)

# %%
# Step 3:  Remove outliers using IQR method
Q1 = np.percentile(house_prices, 25)
Q3 = np.percentile(house_prices, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

prices_no_outliers = house_prices[(house_prices >= lower_bound) & (house_prices <= upper_bound)]
print("Average after removing outliers:", np.mean(prices_no_outliers))
print("Average price (with outliers):", average_price)
print("Total prices:", len(house_prices))
print("Prices after removing outliers:", len(prices_no_outliers))
# Out:
# Average after removing outliers: 499870.138055643
# Average price (with outliers): 499786.4016631574
# Total prices: 10000
# Prices after removing outliers: 9917

# %%
#how many outliers removed
outliers_removed = len(house_prices) - len(prices_no_outliers)
print("Outliers removed:", outliers_removed)
# Out:
# Outliers removed: 83

# %%
# step 4. Visualize price distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(house_prices, bins=50, edgecolor='black', alpha=0.7)
axes[0].set_title('House Price Distribution')
axes[0].set_xlabel('Price ($)')
axes[0].set_ylabel('Frequency')
axes[0].axvline(average_price, color='red', linestyle='--', label=f'Average: ${average_price:,.0f}')
axes[0].legend()

# Box plot (fixed warning)
axes[1].boxplot([house_prices, prices_no_outliers], tick_labels=['With Outliers', 'Without Outliers'])
axes[1].set_title('House Prices: Box Plot Comparison')
axes[1].set_ylabel('Price ($)')

plt.tight_layout()
plt.show()
