# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("customer_churnn.csv")
df
# Out:
#     CustomerID   Age  Gender   Salary Churn
# 0          101  25.0    Male    40000    No
# 1          102   NaN  FEMALE    42000   Yes
# 2          103  35.0  female    39000    No
# 3          104  45.0       M  1200000    No
# 4          105  28.0    male    41000   Yes
# 5          106  35.0       F    39000    No
# 6          107  35.0       F    39000    No
# 7          108   NaN    Male    38000   Yes
# 8          109  52.0  Female    45000    No
# 9          110  23.0    Male    37000   Yes
# 10         111  29.0    MALE  9999999    No
# 11         112  41.0  female    43000    No
# 12         113  38.0       F    44000   Yes
# 13         114   NaN       m    40000    No
# 14         115  34.0  FEMALE    41000   Yes
# 15         116  35.0       F    39000    No
# 16         116  35.0       F    39000    No
# 17         117  27.0       M    36000   Yes
# 18         118  48.0  Female    47000    No
# 19         119  31.0    MALE    39000   Yes
# 20         120   NaN  female    42000    No

# %%
df.head()
# Out:
#    CustomerID   Age  Gender   Salary Churn
# 0         101  25.0    Male    40000    No
# 1         102   NaN  FEMALE    42000   Yes
# 2         103  35.0  female    39000    No
# 3         104  45.0       M  1200000    No
# 4         105  28.0    male    41000   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  21 non-null     int64
#  1   Age         17 non-null     float64
#  2   Gender      21 non-null     object
#  3   Salary      21 non-null     int64
#  4   Churn       21 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 972.0+ bytes

# %%
df.isnull().sum()
# Out:
# CustomerID    0
# Age           4
# Gender        0
# Salary        0
# Churn         0
# dtype: int64

# %%
df.describe()
# Out:
#        CustomerID        Age        Salary
# count   21.000000  17.000000  2.100000e+01
# mean   110.761905  35.058824  5.700000e+05
# std      5.889862   7.956684  2.175413e+06
# min    101.000000  23.000000  3.600000e+04
# 25%    106.000000  29.000000  3.900000e+04
# 50%    111.000000  35.000000  4.000000e+04
# 75%    116.000000  38.000000  4.300000e+04
# max    120.000000  52.000000  9.999999e+06

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID   Age  Gender   Salary Churn
# 0          101  25.0    Male    40000    No
# 1          102   NaN  FEMALE    42000   Yes
# 2          103  35.0  female    39000    No
# 3          104  45.0       M  1200000    No
# 4          105  28.0    male    41000   Yes
# 5          106  35.0       F    39000    No
# 6          107  35.0       F    39000    No
# 7          108   NaN    Male    38000   Yes
# 8          109  52.0  Female    45000    No
# 9          110  23.0    Male    37000   Yes
# 10         111  29.0    MALE  9999999    No
# 11         112  41.0  female    43000    No
# 12         113  38.0       F    44000   Yes
# 13         114   NaN       m    40000    No
# 14         115  34.0  FEMALE    41000   Yes
# 15         116  35.0       F    39000    No
# 17         117  27.0       M    36000   Yes
# 18         118  48.0  Female    47000    No
# 19         119  31.0    MALE    39000   Yes
# 20         120   NaN  female    42000    No

# %%
mean_age = df["Age"].mean()
df["Age"] = df["Age"].fillna(mean_age)
df.isnull().sum()
# Out:
# C:\Users\danis\AppData\Local\Temp\ipykernel_21152\3737201080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].fillna(mean_age)
# CustomerID    0
# Age           0
# Gender        0
# Salary        0
# Churn         0
# dtype: int64

# %%
df["Gender"] = df["Gender"].str.lower()

df["Gender"] = df["Gender"].replace({
    "m": "male",
    "f": "female"
})
# Out:
# C:\Users\danis\AppData\Local\Temp\ipykernel_21152\4128421267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"] = df["Gender"].str.lower()
# C:\Users\danis\AppData\Local\Temp\ipykernel_21152\4128421267.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"] = df["Gender"].replace({

# %%
df
# Out:
#     CustomerID      Age  Gender   Salary Churn
# 0          101  25.0000    male    40000    No
# 1          102  35.0625  female    42000   Yes
# 2          103  35.0000  female    39000    No
# 3          104  45.0000    male  1200000    No
# 4          105  28.0000    male    41000   Yes
# 5          106  35.0000  female    39000    No
# 6          107  35.0000  female    39000    No
# 7          108  35.0625    male    38000   Yes
# 8          109  52.0000  female    45000    No
# 9          110  23.0000    male    37000   Yes
# 10         111  29.0000    male  9999999    No
# 11         112  41.0000  female    43000    No
# 12         113  38.0000  female    44000   Yes
# 13         114  35.0625    male    40000    No
# 14         115  34.0000  female    41000   Yes
# 15         116  35.0000  female    39000    No
# 17         117  27.0000    male    36000   Yes
# 18         118  48.0000  female    47000    No
# 19         119  31.0000    male    39000   Yes
# 20         120  35.0625  female    42000    No

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df["Salary"] >= lower_bound) & (df["Salary"] <= upper_bound)]

# %%
df
# Out:
#     CustomerID      Age  Gender  Salary Churn
# 0          101  25.0000    male   40000    No
# 1          102  35.0625  female   42000   Yes
# 2          103  35.0000  female   39000    No
# 4          105  28.0000    male   41000   Yes
# 5          106  35.0000  female   39000    No
# 6          107  35.0000  female   39000    No
# 7          108  35.0625    male   38000   Yes
# 8          109  52.0000  female   45000    No
# 9          110  23.0000    male   37000   Yes
# 11         112  41.0000  female   43000    No
# 12         113  38.0000  female   44000   Yes
# 13         114  35.0625    male   40000    No
# 14         115  34.0000  female   41000   Yes
# 15         116  35.0000  female   39000    No
# 17         117  27.0000    male   36000   Yes
# 19         119  31.0000    male   39000   Yes
# 20         120  35.0625  female   42000    No

# %%
df.isnull().sum()
# Out:
# CustomerID    0
# Age           0
# Gender        0
# Salary        0
# Churn         0
# dtype: int64

# %%
df
# Out:
#     CustomerID      Age  Gender  Salary Churn
# 0          101  25.0000    male   40000    No
# 1          102  35.0625  female   42000   Yes
# 2          103  35.0000  female   39000    No
# 4          105  28.0000    male   41000   Yes
# 5          106  35.0000  female   39000    No
# 6          107  35.0000  female   39000    No
# 7          108  35.0625    male   38000   Yes
# 8          109  52.0000  female   45000    No
# 9          110  23.0000    male   37000   Yes
# 11         112  41.0000  female   43000    No
# 12         113  38.0000  female   44000   Yes
# 13         114  35.0625    male   40000    No
# 14         115  34.0000  female   41000   Yes
# 15         116  35.0000  female   39000    No
# 17         117  27.0000    male   36000   Yes
# 19         119  31.0000    male   39000   Yes
# 20         120  35.0625  female   42000    No

# %%
df.to_csv("customer_churn_cleaned.csv", index=False)
df
# Out:
#     CustomerID      Age  Gender  Salary Churn
# 0          101  25.0000    male   40000    No
# 1          102  35.0625  female   42000   Yes
# 2          103  35.0000  female   39000    No
# 4          105  28.0000    male   41000   Yes
# 5          106  35.0000  female   39000    No
# 6          107  35.0000  female   39000    No
# 7          108  35.0625    male   38000   Yes
# 8          109  52.0000  female   45000    No
# 9          110  23.0000    male   37000   Yes
# 11         112  41.0000  female   43000    No
# 12         113  38.0000  female   44000   Yes
# 13         114  35.0625    male   40000    No
# 14         115  34.0000  female   41000   Yes
# 15         116  35.0000  female   39000    No
# 17         117  27.0000    male   36000   Yes
# 19         119  31.0000    male   39000   Yes
# 20         120  35.0625  female   42000    No
