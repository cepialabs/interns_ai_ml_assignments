# %%
import pandas as pd
import numpy as np

# Create sample student performance dataset
np.random.seed(42)

data = {
    "StudentID": range(1, 101),
    "Gender": np.random.choice(["Male", "Female"], 100),
    "Attendance": np.random.randint(60, 101, 100),   # Attendance %
    "StudyHours": np.random.randint(1, 10, 100),
    "MathScore": np.random.randint(40, 100, 100),
    "ReadingScore": np.random.randint(45, 100, 100),
    "WritingScore": np.random.randint(50, 100, 100)
}

df = pd.DataFrame(data)

# Create an overall score
df["TotalScore"] = df[["MathScore", "ReadingScore", "WritingScore"]].mean(axis=1)

df.head()
# Out:
#    StudentID  Gender  Attendance  StudyHours  MathScore  ReadingScore  \
# 0          1    Male          77           3         87            46
# 1          2  Female          85           7         64            71
# 2          3    Male          93           6         74            86
# 3          4    Male          69           8         64            46
# 4          5    Male          95           9         68            70
#
#    WritingScore  TotalScore
# 0            50   61.000000
# 1            65   66.666667
# 2            88   82.666667
# 3            54   54.666667
# 4            71   69.666667

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure()
sns.histplot(df["TotalScore"], bins=10, kde=True)
plt.title("Score Distribution")
plt.xlabel("Average Score")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure()
sns.boxplot(x="Gender", y="TotalScore", data=df)
plt.title("Gender vs Performance")
plt.xlabel("Gender")
plt.ylabel("Average Score")
plt.show()

# %%
plt.figure(figsize=(8,6))
corr = df[["Attendance", "StudyHours", "MathScore", "ReadingScore", "WritingScore", "TotalScore"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure()
sns.regplot(x="Attendance", y="TotalScore", data=df)
plt.title("Attendance vs Score Trend")
plt.xlabel("Attendance (%)")
plt.ylabel("Average Score")
plt.show()
