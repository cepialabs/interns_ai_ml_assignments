# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
n = 200

data = pd.DataFrame({
    "Gender": np.random.choice(["Male", "Female"], n),
    "Attendance": np.random.randint(55, 100, n),
    "Math_Score": np.random.randint(40, 100, n),
    "Science_Score": np.random.randint(35, 100, n),
    "English_Score": np.random.randint(45, 100, n)
})

data["Average_Score"] = data[["Math_Score", "Science_Score", "English_Score"]].mean(axis=1)
data.head()
# Out:
#    Gender  Attendance  Math_Score  Science_Score  English_Score  Average_Score
# 0    Male          86          72             67             45      61.333333
# 1  Female          93          42             67             98      69.000000
# 2    Male          86          57             95             88      80.000000
# 3    Male          58          64             85             49      66.000000
# 4    Male          84          81             77             74      77.333333

# %%
plt.figure()
plt.hist(data["Average_Score"])
plt.title("Score Distribution")
plt.xlabel("Average Score")
plt.ylabel("Number of Students")
plt.show()

# %%
gender_perf = data.groupby("Gender")["Average_Score"].mean()

plt.figure()
plt.bar(gender_perf.index, gender_perf.values)
plt.title("Gender vs Average Performance")
plt.xlabel("Gender")
plt.ylabel("Average Score")
plt.show()

# %%
corr = data[["Attendance", "Math_Score", "Science_Score", "English_Score", "Average_Score"]].corr()

plt.figure()
plt.imshow(corr)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.scatter(data["Attendance"], data["Average_Score"])
plt.title("Attendance vs Average Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Average Score")
plt.show()
