# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. Generate 10,000 random house prices
np.random.seed(42) 
prices = np.random.normal(loc=300_000, scale=50_000, size=10_000)
average_price = np.mean(prices)
print(f"Average house price (before outlier removal): ${average_price:,.2f}")
# Out:
# Average house price (before outlier removal): $299,893.20

# %%
# 2. Remove outliers 
q1 = np.percentile(prices, 25)
q3 = np.percentile(prices, 75)
iqr = q3 - q1

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

filtered_prices = prices[
    (prices >= lower_bound) & (prices <= upper_bound)
]

filtered_average = np.mean(filtered_prices)
print(f"Average house price (after outlier removal): ${filtered_average:,.2f}")
print(f"Number of prices after removing outliers: {len(filtered_prices)}")
# Out:
# Average house price (after outlier removal): $299,935.07
# Number of prices after removing outliers: 9917

# %%
# 3. Visualize price distribution
plt.hist(filtered_prices, bins=50)
plt.xlabel("House Price")
plt.ylabel("Frequency")
plt.title("House Price Distribution (Outliers Removed)")
plt.show()
