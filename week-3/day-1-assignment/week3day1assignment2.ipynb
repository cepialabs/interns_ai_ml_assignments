# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(
    r"C:\Users\Seerat Metkari\Downloads\customer_data.csv"
)
df.head()
# Out:
#    Customer Reference ID Item Purchased  Purchase Amount (USD) Date Purchase  \
# 0                   4018        Handbag                 4619.0    05-02-2023
# 1                   4115          Tunic                 2456.0    11-07-2023
# 2                   4019       Tank Top                 2102.0    23-03-2023
# 3                   4097       Leggings                 3126.0    15-03-2023
# 4                   3997         Wallet                 3003.0    27-11-2022
#
#    Review Rating Payment Method
# 0            NaN    Credit Card
# 1            2.0    Credit Card
# 2            4.1           Cash
# 3            3.2           Cash
# 4            4.7           Cash

# %%
X = df[["Purchase Amount (USD)", "Review Rating"]]

# %%
X = X.dropna()

# %%
df_clean = df.dropna(subset=["Purchase Amount (USD)", "Review Rating"])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df_clean["Cluster"] = kmeans.fit_predict(X_scaled)

# %%
X = df_clean[["Purchase Amount (USD)", "Review Rating"]]

# %%
import matplotlib.pyplot as plt

plt.scatter(
    df_clean["Purchase Amount (USD)"],
    df_clean["Review Rating"],
    c=df_clean["Cluster"]
)
plt.xlabel("Purchase Amount (USD)")
plt.ylabel("Review Rating")
plt.title("Customer Segmentation")
plt.show()
